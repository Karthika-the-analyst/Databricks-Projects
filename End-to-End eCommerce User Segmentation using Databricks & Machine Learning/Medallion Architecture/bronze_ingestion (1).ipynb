# %% [markdown]
# ### Bronze Layer
# Raw e-commerce event data is ingested from Amazon S3 using Unity Catalog External Locations.
# Data is stored in Delta format without business transformations to preserve raw fidelity.
# Ingestion metadata, including load timestamp and source file path (_metadata.file_path), is captured to enable auditability and lineage within Unity Catalog.

# %% [markdown]
# ## Create schema

# %%
# %sql
CREATE SCHEMA IF NOT EXISTS e_commerce_capstone.bronze;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

# %% [markdown]
# Set catalog & schema

# %%
# %sql
USE CATALOG e_commerce_capstone;
USE SCHEMA bronze;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

# %% [markdown]
# ## Read raw CSVs from S3

# %%
raw_df = (
    spark.read
         .option("header", "true")
         .option("inferSchema", "true")
         .csv("s3://ecommerce-capstone-raw/*.csv")
)

# %% [markdown]
# Add ingestion metadata (best practice)

# %%
from pyspark.sql.functions import current_timestamp, col

bronze_df = (
    raw_df
    .withColumn("ingestion_timestamp", current_timestamp())
    .withColumn("source_file", col("_metadata.file_path"))
)

# %% [markdown]
# ## Write Bronze Delta table

# %%
(
    bronze_df
    .write
    .format("delta")
    .mode("overwrite")
    .saveAsTable("raw_events")
)

# %% [markdown]
# Validate Bronze

# %%
# %sql
SELECT COUNT(*) FROM e_commerce_capstone.bronze.raw_events;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>COUNT(*)</th></tr></thead><tbody><tr><td>411709736</td></tr></tbody></table></div>

# %%
# %sql
SELECT source_file, ingestion_timestamp
FROM e_commerce_capstone.bronze.raw_events
LIMIT 10;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>source_file</th><th>ingestion_timestamp</th></tr></thead><tbody><tr><td>s3://ecommerce-capstone-raw/2019-Dec.csv</td><td>2026-01-31T17:09:52.595Z</td></tr><tr><td>s3://ecommerce-capstone-raw/2019-Dec.csv</td><td>2026-01-31T17:09:52.595Z</td></tr><tr><td>s3://ecommerce-capstone-raw/2019-Dec.csv</td><td>2026-01-31T17:09:52.595Z</td></tr><tr><td>s3://ecommerce-capstone-raw/2019-Dec.csv</td><td>2026-01-31T17:09:52.595Z</td></tr><tr><td>s3://ecommerce-capstone-raw/2019-Dec.csv</td><td>2026-01-31T17:09:52.595Z</td></tr><tr><td>s3://ecommerce-capstone-raw/2019-Dec.csv</td><td>2026-01-31T17:09:52.595Z</td></tr><tr><td>s3://ecommerce-capstone-raw/2019-Dec.csv</td><td>2026-01-31T17:09:52.595Z</td></tr><tr><td>s3://ecommerce-capstone-raw/2019-Dec.csv</td><td>2026-01-31T17:09:52.595Z</td></tr><tr><td>s3://ecommerce-capstone-raw/2019-Dec.csv</td><td>2026-01-31T17:09:52.595Z</td></tr><tr><td>s3://ecommerce-capstone-raw/2019-Dec.csv</td><td>2026-01-31T17:09:52.595Z</td></tr></tbody></table></div>
